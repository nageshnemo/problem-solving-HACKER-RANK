# %%
no = int(input())
fact = 1
count = 0
while no != 0:
    fact = fact * no
    no -=1
    
print (fact)

while fact != 0:
    rem = fact % 10 
    if rem == 0:
        count +=1 
    fact /=10
    print (fact)
        
        
print(count)
# Out:
# 12
# 479001600
# 47900160.0
# 4790016.0
# 479001.6
# 47900.159999999996
# 4790.016
# 479.00159999999994
# 47.90015999999999
# 4.790016
# 0.47900159999999997
# 0.04790016
# 0.004790015999999999
# 0.00047900159999999994
# 4.7900159999999996e-05
# 4.7900159999999995e-06
# 4.790016e-07
# 4.790016e-08
# 4.7900159999999995e-09
# 4.790016e-10
# 4.790016e-11
# 4.790016e-12
# 4.790016e-13
# 4.790016e-14
# 4.790016e-15
# 4.790016e-16
# 4.790016e-17
# 4.790016e-18
# 4.790016e-19
# 4.790016e-20
# 4.7900159999999996e-21
# 4.790015999999999e-22
# 4.7900159999999995e-23
# 4.790015999999999e-24
# 4.790015999999999e-25
# 4.790015999999999e-26
# 4.790015999999999e-27
# 4.790015999999999e-28
# 4.790015999999999e-29
# 4.790015999999999e-30
# 4.790015999999999e-31
# 4.790015999999999e-32
# 4.790015999999999e-33
# 4.790015999999999e-34
# 4.790015999999999e-35
# 4.790015999999999e-36
# 4.790015999999999e-37
# 4.790015999999999e-38
# 4.7900159999999984e-39
# 4.790015999999998e-40
# 4.790015999999999e-41
# ...

# %%
123 % 10
# Out:
# 3
